# %%
from databricks.connect import DatabricksSession
spark = (
    DatabricksSession.builder
    .profile("apd_mwang")
    .serverless(True)
    .getOrCreate()
)

# %%
df = spark.sql("SELECT * FROM main.ahusain.customers_raw")
df.show(truncate=False)
# Out:
# +-----------+----------------+----------------------------+
# |customer_id|name            |email                       |
# +-----------+----------------+----------------------------+
# |1          |Customer User 1 |Customer User 1@example.com |
# |2          |Customer User 2 |Customer User 2@example.com |
# |3          |Customer User 3 |Customer User 3@example.com |
# |4          |Customer User 4 |Customer User 4@example.com |
# |5          |Customer User 5 |Customer User 5@example.com |
# |6          |Customer User 6 |Customer User 6@example.com |
# |7          |Customer User 7 |Customer User 7@example.com |
# |8          |Customer User 8 |Customer User 8@example.com |
# |9          |Customer User 9 |Customer User 9@example.com |
# |10         |Customer User 10|Customer User 10@example.com|
# |11         |Customer User 11|Customer User 11@example.com|
# |12         |Customer User 12|Customer User 12@example.com|
# |13         |Customer User 13|Customer User 13@example.com|
# ...
